# %% [markdown]
# <h3>Tableau Project<h3>

# %% [markdown]
# I chose to do a quick analysis and data cleanse in python before using the data in Tableau. The reason for this choice was to easily deal with Null values, and allow for a deeper understanding of the data prior to using Tableau for visualizations

# %%
import pandas as pd

# %%
df = pd.read_csv('Data/airbnb.csv')
df.head()
# Out:
#     Host Id  Host Since                                Name Neighbourhood   \
# 0   5162530         NaN     1 Bedroom in Prime Williamsburg       Brooklyn
# 1  33134899         NaN     Sunny, Private room in Bushwick       Brooklyn
# 2  39608626         NaN                Sunny Room in Harlem      Manhattan
# 3       500  2008-06-26  Gorgeous 1 BR with Private Balcony      Manhattan
# 4       500  2008-06-26            Trendy Times Square Loft      Manhattan
#
#   Property Type  Review Scores Rating (bin)        Room Type  Zipcode  Beds  \
# 0     Apartment                         NaN  Entire home/apt  11249.0   1.0
# 1     Apartment                         NaN     Private room  11206.0   1.0
# 2     Apartment                         NaN     Private room  10032.0   1.0
# 3     Apartment                         NaN  Entire home/apt  10024.0   3.0
# 4     Apartment                        95.0     Private room  10036.0   3.0
#
#    Number of Records  Number Of Reviews Price  Review Scores Rating
# 0                  1                  0   145                   NaN
# 1                  1                  1    37                   NaN
# 2                  1                  1    28                   NaN
# 3                  1                  0   199                   NaN
# 4                  1                 39   549                  96.0

# %%
#check the columns
df.columns

#noticed extra whitespace on Neighbourhood column so I removed it
df['Neighbourhood'] = df['Neighbourhood '].str.strip()

# %%
#check the data types
df.dtypes
# Out:
# Host Id                         int64
# Host Since                     object
# Name                           object
# Neighbourhood                  object
# Property Type                  object
# Review Scores Rating (bin)    float64
# Room Type                      object
# Zipcode                       float64
# Beds                          float64
# Number of Records               int64
# Number Of Reviews               int64
# Price                          object
# Review Scores Rating          float64
# Neighbourhood                  object
# dtype: object

# %% [markdown]
# <h5>Clean the Data<h5>

# %%
df.describe()
# Out:
#             Host Id  Review Scores Rating (bin)       Zipcode          Beds  \
# count  3.047800e+04                22664.000000  30344.000000  30393.000000
# mean   1.273171e+07                   90.738659  10584.854831      1.530089
# std    1.190270e+07                    8.957205    921.299397      1.015359
# min    5.000000e+02                   20.000000   1003.000000      0.000000
# 25%    2.701298e+06                   85.000000  10017.000000      1.000000
# 50%    8.551693e+06                   90.000000  10065.000000      1.000000
# 75%    2.120617e+07                   95.000000  11216.000000      2.000000
# max    4.303307e+07                  100.000000  99135.000000     16.000000
#
#        Number of Records  Number Of Reviews  Review Scores Rating
# count            30478.0       30478.000000          22664.000000
# mean                 1.0          12.018735             91.993230
# std                  0.0          21.980703              8.750421
# min                  1.0           0.000000             20.000000
# 25%                  1.0           0.000000             89.000000
# 50%                  1.0           3.000000             93.000000
# 75%                  1.0          13.000000             99.000000
# max                  1.0         257.000000            100.000000

# %%
NaN_count = df[df['Number Of Reviews'] > 0].isna().sum()

#use imputation to put the Mean review score in 'Number of Reviews' and 'Number of Reviews' where there is > 0 reviews
mean_review_bin = df[df['Number Of Reviews'] > 0]['Review Scores Rating (bin)'].mean()
mean_review = df[df['Number Of Reviews'] > 0]['Review Scores Rating'].mean()

#impute the data into the NaN columns
df.loc[df['Number Of Reviews'] > 0, 'Review Scores Rating'] = df.loc[df['Number Of Reviews'] > 0, 'Review Scores Rating'].fillna(mean_review)
df.loc[df['Number Of Reviews'] > 0, 'Review Scores Rating (bin)'] = df.loc[df['Number Of Reviews'] > 0, 'Review Scores Rating (bin)'].fillna(mean_review_bin)

# %%
#recheck the count
print(NaN_count)
# Out:
# Host Id                         0
# Host Since                      2
# Name                            0
# Neighbourhood                   0
# Property Type                   2
# Review Scores Rating (bin)      0
# Room Type                       0
# Zipcode                       104
# Beds                           46
# Number of Records               0
# Number Of Reviews               0
# Price                           0
# Review Scores Rating            0
# dtype: int64

# %% [markdown]
# Clean the Zipcode data by adding the correct zipcode if its missing

# %%
#check the number of neighbourhoods
df['Neighbourhood'].value_counts()
# Out:
# Neighbourhood
# Manhattan        16033
# Brooklyn         11675
# Queens            2278
# Bronx              345
# Staten Island      147
# Name: count, dtype: int64

# %%
#check the data for manhattan neighbourhood places with no zipcode
df.loc[(df['Neighbourhood'] == 'Manhattan') & (df['Zipcode'].isna())]
# Out:
#         Host Id  Host Since                                 Name  \
# 133       13654  2009-04-16   Room with a view in Central Harlem
# 234       30990  2009-08-11    Stay in the Meatpacking District!
# 368       52677  2009-11-09            Columbus Avenue Apartment
# 426       58366  2009-11-29        Lincoln Center  luxury condo,
# 464       60944  2009-12-07  Alcove Studio West Village DrmnBldg
# 705      101172  2010-03-30      1 BR loft 5 min walk to Time Sq
# 706      101172  2010-03-30  1BR w/terrace 5 min walk to Time Sq
# 707      101172  2010-03-30     Luxury 1BR 5 min walk to Time Sq
# 708      101172  2010-03-30    Modern 1 BR 5 min walk to Time Sq
# 709      101172  2010-03-30    Unique Loft 5 min walk to Time Sq
# 1629     283395  2010-11-10  Hip Loft Style Apt. IDEAL Location!
# 1633     283395  2010-11-10  Double BEDRM in Loft Ideal Location
# 1707     299015  2010-11-25   1-BR Apt in the Heart of Manhattan
# 1731     304081  2010-11-29         Great Studio, Great Location
# 2087     390251  2011-02-13                   MI CASA ES TU CASA
# 2672     593927  2011-05-16  Modern apartment / Perfect Location
# 3058     732985  2011-06-22  Perfect Pied a Terre in Meatpacking
# 4619    1394049  2011-11-10                  PRIVATE BATH & ROOM
# 4620    1394049  2011-11-10                  PRIVATE ROOM & BATH
# 4815    1439416  2011-11-24       STUNNING 2 BDRM - TIMES SQUARE
# 5607    1708418  2012-02-06          Sunny 1BR  loft TIME SQUARE
# 6954    2358573  2012-05-13         Light, spacious and central!
# 8089    2966244  2012-07-17      Comfortable 1br in West Village
# 8362    3126013  2012-08-01      Amazing, spacious, modern home!
# 8616    3264033  2012-08-15   4Bedrooms / Roof Deck / Center NYC
# 9230    3637246  2012-09-21   Large Private Room by Central Park
# 9490    3818092  2012-10-09   Gorgeous NYC Interior Designer Apt
# 10326   4251217  2012-11-26  Huge, Sunny, Top Floor, Comfy home!
# 10584   4349699  2012-12-07   Georgeos/cozy 1 bed apt in Chelsea
# 10618   4363133  2012-12-09   ★ Large Prime Cozy E Village Apt ★
# 10688   4385409  2012-12-12     Watch Game of Thrones in theater
# 11720   5166070  2013-02-20      3bed 2 bath Duplex ! No walk up
# 11978   5360659  2013-03-07   Gorgeous Space, Industrial NYC Apt
# 12017   5386585  2013-03-09    Massive Apartment in West Village
# 12316   5667385  2013-03-28    2 BR Modern Apt near Central Park
# 12332   5664550  2013-03-28    Private Room w TV in East Village
# 12430   5744776  2013-04-03        STRIKE WHEN THE IRON IS HOT!!
# 12576   5910738  2013-04-13    Spacious 1BR in great Harlem area
# 12939   6223363  2013-05-04   2 bedroom near Columbia University
# 15336   8700888  2013-09-08    Manhattan NY Central Park Cosy 1B
# 15901   9351405  2013-10-10  SUPER CLEAN 2 BED CRASH PAD IN NYC!
# 15902   9351405  2013-10-10  Sweet Broadway Apt! Superduper Deal
# 16102   9586465  2013-10-23   3 beds with loft near Central Park
# 17088  10583579  2013-12-12  Shared two bedroom in Gramercy Park
# 17168  10661984  2013-12-16  CLEAN, QUIET COMFORT in CHELSEA !!!
# 18106  11947308  2014-02-04      Cozy Bedroom in Lower East Side
# 18361  12351216  2014-02-18  Huge space and MILLION DOLLAR VIEWS
# 20624  16978260  2014-06-19            BEAUTIFUL SPACIOUS STUDIO
# 21269  18061086  2014-07-13    Huge Bedroom - East Village - NYC
# 22990  21508969  2014-09-19  Manhattan Lifestyle Upper East Side
# 23266  22051787  2014-10-02       ★VINTAGE HOUSE ★ CENTRAL PARK★
# 23830  23076444  2014-10-28      Cozy 1BD East Village/Downtown.
# 25349  25517905  2015-01-02          Beautiful Central Park View
# 26360  28839935  2015-03-05      Gorgeous and Huge UWS Apartment
# 27492  32793658  2015-05-06                     Le jardin Harlem
# 27568  33064599  2015-05-10    HUGE PRETTY bedroom (female only)
# 29947  40585961  2015-08-05          Large Lower East Side 1 BDR
#
#       Neighbourhood     Property Type  Review Scores Rating (bin)  \
# 133        Manhattan        Apartment                   85.000000
# 234        Manhattan        Apartment                   95.000000
# 368        Manhattan        Apartment                         NaN
# 426        Manhattan        Apartment                   90.000000
# 464        Manhattan        Apartment                         NaN
# 705        Manhattan        Apartment                   85.000000
# 706        Manhattan        Apartment                   85.000000
# 707        Manhattan        Apartment                   85.000000
# 708        Manhattan        Apartment                   85.000000
# 709        Manhattan        Apartment                   80.000000
# 1629       Manhattan        Apartment                  100.000000
# 1633       Manhattan        Apartment                   85.000000
# 1707       Manhattan        Apartment                   90.000000
# 1731       Manhattan        Apartment                   95.000000
# 2087       Manhattan        Apartment                   80.000000
# 2672       Manhattan        Apartment                         NaN
# 3058       Manhattan        Apartment                   95.000000
# 4619       Manhattan        Apartment                   85.000000
# 4620       Manhattan        Apartment                   90.000000
# 4815       Manhattan        Apartment                   90.000000
# 5607       Manhattan        Apartment                   90.000000
# 6954       Manhattan        Apartment                   95.000000
# 8089       Manhattan        Apartment                   90.000000
# 8362       Manhattan        Apartment                   85.000000
# 8616       Manhattan        Apartment                   90.000000
# 9230       Manhattan        Apartment                   85.000000
# 9490       Manhattan        Apartment                   90.000000
# 10326      Manhattan        Apartment                   90.000000
# 10584      Manhattan        Apartment                   95.000000
# 10618      Manhattan        Apartment                   95.000000
# 10688      Manhattan        Apartment                   90.738659
# 11720      Manhattan        Apartment                  100.000000
# 11978      Manhattan        Apartment                   85.000000
# 12017      Manhattan        Apartment                   90.000000
# 12316      Manhattan        Apartment                   95.000000
# 12332      Manhattan        Apartment                   90.000000
# 12430      Manhattan        Apartment                         NaN
# 12576      Manhattan        Apartment                   90.000000
# 12939      Manhattan        Apartment                         NaN
# 15336      Manhattan        Apartment                  100.000000
# 15901      Manhattan        Apartment                   85.000000
# 15902      Manhattan        Apartment                   75.000000
# 16102      Manhattan        Apartment                   65.000000
# 17088      Manhattan        Apartment                         NaN
# 17168      Manhattan        Apartment                  100.000000
# 18106      Manhattan        Apartment                   85.000000
# 18361      Manhattan        Apartment                   95.000000
# 20624      Manhattan  Bed & Breakfast                         NaN
# 21269      Manhattan        Apartment                  100.000000
# 22990      Manhattan        Apartment                   80.000000
# 23266      Manhattan        Apartment                   90.738659
# 23830      Manhattan        Apartment                  100.000000
# 25349      Manhattan        Apartment                   85.000000
# 26360      Manhattan        Apartment                         NaN
# 27492      Manhattan        Apartment                         NaN
# 27568      Manhattan        Apartment                  100.000000
# 29947      Manhattan        Apartment                         NaN
#
#              Room Type  Zipcode  Beds  Number of Records  Number Of Reviews  \
# 133       Private room      NaN   1.0                  1                 11
# 234    Entire home/apt      NaN   1.0                  1                109
# 368       Private room      NaN   1.0                  1                  0
# 426    Entire home/apt      NaN   1.0                  1                 37
# 464    Entire home/apt      NaN   1.0                  1                  0
# 705    Entire home/apt      NaN   3.0                  1                140
# 706    Entire home/apt      NaN   3.0                  1                 78
# 707    Entire home/apt      NaN   3.0                  1                200
# 708    Entire home/apt      NaN   3.0                  1                 79
# 709    Entire home/apt      NaN   3.0                  1                 35
# 1629   Entire home/apt      NaN   2.0                  1                  1
# 1633      Private room      NaN   1.0                  1                 36
# 1707   Entire home/apt      NaN   1.0                  1                  9
# 1731   Entire home/apt      NaN   1.0                  1                 26
# 2087   Entire home/apt      NaN   2.0                  1                  4
# 2672   Entire home/apt      NaN   1.0                  1                  0
# 3058   Entire home/apt      NaN   1.0                  1                  9
# 4619      Private room      NaN   2.0                  1                113
# 4620      Private room      NaN   2.0                  1                108
# 4815   Entire home/apt      NaN   5.0                  1                 56
# 5607   Entire home/apt      NaN   1.0                  1                  6
# 6954   Entire home/apt      NaN   2.0                  1                 12
# 8089   Entire home/apt      NaN   1.0                  1                  2
# 8362   Entire home/apt      NaN   1.0                  1                 33
# 8616   Entire home/apt      NaN   5.0                  1                 57
# 9230      Private room      NaN   1.0                  1                  9
# 9490   Entire home/apt      NaN   3.0                  1                  4
# 10326  Entire home/apt      NaN   2.0                  1                  8
# 10584  Entire home/apt      NaN   1.0                  1                  9
# 10618  Entire home/apt      NaN   2.0                  1                 70
# 10688  Entire home/apt      NaN   1.0                  1                  1
# 11720  Entire home/apt      NaN   5.0                  1                  2
# 11978  Entire home/apt      NaN   5.0                  1                 72
# 12017  Entire home/apt      NaN   4.0                  1                 26
# 12316  Entire home/apt      NaN   2.0                  1                 15
# 12332     Private room      NaN   1.0                  1                 19
# 12430     Private room      NaN   1.0                  1                  0
# 12576  Entire home/apt      NaN   1.0                  1                 14
# 12939  Entire home/apt      NaN   3.0                  1                  0
# 15336  Entire home/apt      NaN   1.0                  1                  2
# 15901  Entire home/apt      NaN   3.0                  1                  8
# 15902  Entire home/apt      NaN   3.0                  1                  5
# 16102  Entire home/apt      NaN   4.0                  1                  8
# 17088  Entire home/apt      NaN   1.0                  1                  0
# 17168  Entire home/apt      NaN   1.0                  1                  4
# 18106     Private room      NaN   1.0                  1                 63
# 18361     Private room      NaN   1.0                  1                 29
# 20624      Shared room      NaN   1.0                  1                  0
# 21269     Private room      NaN   1.0                  1                  7
# 22990  Entire home/apt      NaN   1.0                  1                  6
# 23266  Entire home/apt      NaN   1.0                  1                  1
# 23830     Private room      NaN   1.0                  1                  1
# 25349     Private room      NaN   1.0                  1                 12
# 26360  Entire home/apt      NaN   2.0                  1                  0
# 27492     Private room      NaN   1.0                  1                  0
# 27568     Private room      NaN   1.0                  1                  2
# 29947     Private room      NaN   1.0                  1                  0
#
#       Price  Review Scores Rating Neighbourhood
# 133      75              85.00000     Manhattan
# 234     249              95.00000     Manhattan
# 368     190                   NaN     Manhattan
# 426     280              93.00000     Manhattan
# 464     198                   NaN     Manhattan
# 705     150              89.00000     Manhattan
# 706     150              86.00000     Manhattan
# 707     150              86.00000     Manhattan
# 708     150              89.00000     Manhattan
# 709     150              84.00000     Manhattan
# 1629    350             100.00000     Manhattan
# 1633    125              86.00000     Manhattan
# 1707    180              91.00000     Manhattan
# 1731    160              95.00000     Manhattan
# 2087    139              80.00000     Manhattan
# 2672    600                   NaN     Manhattan
# 3058    225              97.00000     Manhattan
# 4619     85              89.00000     Manhattan
# 4620     99              90.00000     Manhattan
# 4815    450              91.00000     Manhattan
# 5607    170              90.00000     Manhattan
# 6954    260              98.00000     Manhattan
# 8089    200              90.00000     Manhattan
# 8362    199              87.00000     Manhattan
# 8616    500              94.00000     Manhattan
# 9230     89              87.00000     Manhattan
# 9490    800              90.00000     Manhattan
# 10326   285              91.00000     Manhattan
# 10584   180              96.00000     Manhattan
# 10618   215              95.00000     Manhattan
# 10688   204              91.99323     Manhattan
# 11720   723             100.00000     Manhattan
# 11978   239              85.00000     Manhattan
# 12017   600              93.00000     Manhattan
# 12316   200              99.00000     Manhattan
# 12332    95              90.00000     Manhattan
# 12430    75                   NaN     Manhattan
# 12576   140              92.00000     Manhattan
# 12939   150                   NaN     Manhattan
# 15336   140             100.00000     Manhattan
# 15901   100              89.00000     Manhattan
# 15902   100              76.00000     Manhattan
# 16102   199              65.00000     Manhattan
# 17088   200                   NaN     Manhattan
# 17168   200             100.00000     Manhattan
# 18106    70              89.00000     Manhattan
# 18361   144              96.00000     Manhattan
# 20624    70                   NaN     Manhattan
# 21269   125             100.00000     Manhattan
# 22990   200              80.00000     Manhattan
# 23266   195              91.99323     Manhattan
# 23830   190             100.00000     Manhattan
# 25349    99              87.00000     Manhattan
# 26360   250                   NaN     Manhattan
# 27492   175                   NaN     Manhattan
# 27568    99             100.00000     Manhattan
# 29947    85                   NaN     Manhattan

# %%
df.loc[(df['Neighbourhood'] == 'Brooklyn') & (df['Zipcode'].isna())]
# Out:
#         Host Id  Host Since                                 Name  \
# 333       47716  2009-10-22      $45 L train/ 1 bedroom Brooklyn
# 583       72808  2010-01-23  Coney island Entire Apt Safari Wi F
# 1422     250633  2010-10-01        Historic Ditmas Park Brooklyn
# 1930     335272  2011-01-04   Summer Green Quiet Room Park Slope
# 2085     389924  2011-02-13  Gorgeous French Garden cottage-N 8t
# 2643     580566  2011-05-11  Big bright room, great neighborhood
# 3120     751530  2011-06-27      Room in three-Bedroom Apartment
# 4013    1179779  2011-09-19   Private loft with 2 beds /bathroom
# 4479    1349430  2011-10-29        Huge beautiful 1 bedroom loft
# 5028    1494118  2011-12-11            Peaceful Townhouse Duplex
# 5848    1826769  2012-02-28   Cozy apt in heart of Williamsburg!
# 5884    1834658  2012-02-29        HUGE ROOM IN THE BEST AREA!!!
# 6398    2093542  2012-04-08       Beautiful room in Williamsburg
# 6696    2260108  2012-04-30  Charming sunny studio - Boerum Hill
# 6924    2347313  2012-05-11    City Skyline Views by Bedford Ave
# 7207    2496464  2012-05-29  Unique NYDesigner apt min from all!
# 7490    2648940  2012-06-15  Crown Heights retreat near 2 train!
# 7791    2781725  2012-06-29   COSY AND SPACIOUS ROOM IN BROOKLYN
# 8568    3249777  2012-08-13   Stunning Light/Roof - Williamsburg
# 8805    3370169  2012-08-25   One Bedroom with your own bathroom
# 9183    3608781  2012-09-18        Inspiring spacious loft space
# 9221    3633850  2012-09-21         Spacious Brooklyn NYC Rental
# 9595    3880573  2012-10-15  "The Country" & the NYC Waterfront!
# 10238   4201022  2012-11-20    Large Studio Apt on Prospect Park
# 12105   5480570  2013-03-15  Charming Apt. In Brooklyn Townhouse
# 12630   5954669  2013-04-16  Sun Drenched 1Brm Duplex 2balconies
# 13985   7130382  2013-06-26  NYC - CLINTON HILL - FURNISHED ROOM
# 14354   7529823  2013-07-16       Private room. Modern Apartment
# 14361   7550143  2013-07-17    Large Williamsburg Loft Apartment
# 14812   8055051  2013-08-09      Private Rooms in a Basement Apt
# 15824   9269415  2013-10-06  Modern apartment  Квартира у океана
# 15999   9478849  2013-10-17        Cosy 2br 20 min from the city
# 16116   9614926  2013-10-24  Rockaway Castles Private 3 bedroom!
# 16243   9773998  2013-11-02    East River Queen, & outdoor deck!
# 17635  11237450  2014-01-12                          Modern 1-BR
# 18373  12405344  2014-02-19         European artist's cozy place
# 18817  13451045  2014-03-23     Pull-out Sofa in Our Living Room
# 19226  14314025  2014-04-15         Room in beautiful brownstone
# 19507  14892152  2014-04-29   Quiet*Spacious*Private Bath*Sunny!
# 20016  15891365  2014-05-23   Deck View in Heart of Williamsburg
# 20270  16437254  2014-06-05                Fort Greene Sanctuary
# 22685  21020951  2014-09-06  Spacious room for one or two guest.
# 23978  23309210  2014-11-03  Beautiful & Cozy room, Worry free!!
# 24575  24243859  2014-11-28               Gabriel's Luxury Suite
# 24897  24691848  2014-12-10             Brooklyn Museum, Airbed!
# 25013  24865947  2014-12-15   Cozy ENTIRE APT 1 Bedroom Brooklyn
# 25679  26440427  2015-01-20    CHIC 2 Bdrm in Classic Brownstone
# 26456  29098546  2015-03-10        Private bedroom in 3 bdrm apt
# 27089  31463196  2015-04-18  Private room in NY -Close to subway
# 28995  37248069  2015-07-01                Room on Prospect Park
#
#       Neighbourhood  Property Type  Review Scores Rating (bin)  \
# 333         Brooklyn     Apartment                   85.000000
# 583         Brooklyn     Apartment                   90.000000
# 1422        Brooklyn     Apartment                  100.000000
# 1930        Brooklyn         House                   95.000000
# 2085        Brooklyn     Apartment                   90.000000
# 2643        Brooklyn     Apartment                   85.000000
# 3120        Brooklyn     Apartment                         NaN
# 4013        Brooklyn     Apartment                   90.000000
# 4479        Brooklyn     Apartment                   90.000000
# 5028        Brooklyn         House                  100.000000
# 5848        Brooklyn     Apartment                   95.000000
# 5884        Brooklyn     Apartment                         NaN
# 6398        Brooklyn     Apartment                         NaN
# 6696        Brooklyn     Apartment                  100.000000
# 6924        Brooklyn     Apartment                   95.000000
# 7207        Brooklyn         House                   90.000000
# 7490        Brooklyn     Apartment                         NaN
# 7791        Brooklyn     Apartment                   90.000000
# 8568        Brooklyn     Apartment                         NaN
# 8805        Brooklyn     Apartment                  100.000000
# 9183        Brooklyn          Loft                   95.000000
# 9221        Brooklyn         House                  100.000000
# 9595        Brooklyn     Apartment                   90.000000
# 10238       Brooklyn     Apartment                   95.000000
# 12105       Brooklyn     Apartment                   95.000000
# 12630       Brooklyn     Apartment                   90.738659
# 13985       Brooklyn     Apartment                  100.000000
# 14354       Brooklyn     Apartment                   95.000000
# 14361       Brooklyn     Apartment                   95.000000
# 14812       Brooklyn     Apartment                   90.000000
# 15824       Brooklyn     Apartment                  100.000000
# 15999       Brooklyn     Apartment                   80.000000
# 16116       Brooklyn     Apartment                         NaN
# 16243       Brooklyn         House                   90.000000
# 17635       Brooklyn     Apartment                   95.000000
# 18373       Brooklyn     Apartment                  100.000000
# 18817       Brooklyn     Apartment                         NaN
# 19226       Brooklyn     Apartment                         NaN
# 19507       Brooklyn     Apartment                  100.000000
# 20016       Brooklyn     Apartment                   80.000000
# 20270       Brooklyn     Apartment                  100.000000
# 22685       Brooklyn     Apartment                   90.000000
# 23978       Brooklyn         House                   90.000000
# 24575       Brooklyn     Apartment                   90.000000
# 24897       Brooklyn     Apartment                   95.000000
# 25013       Brooklyn     Apartment                   80.000000
# 25679       Brooklyn     Apartment                   95.000000
# 26456       Brooklyn     Apartment                   80.000000
# 27089       Brooklyn     Apartment                   95.000000
# 28995       Brooklyn     Apartment                         NaN
#
#              Room Type  Zipcode  Beds  Number of Records  Number Of Reviews  \
# 333       Private room      NaN   2.0                  1                 56
# 583    Entire home/apt      NaN   2.0                  1                 83
# 1422      Private room      NaN   1.0                  1                  3
# 1930      Private room      NaN   1.0                  1                 99
# 2085   Entire home/apt      NaN   1.0                  1                 38
# 2643      Private room      NaN   1.0                  1                  7
# 3120   Entire home/apt      NaN   1.0                  1                  0
# 4013   Entire home/apt      NaN   2.0                  1                 43
# 4479   Entire home/apt      NaN   2.0                  1                 58
# 5028   Entire home/apt      NaN   2.0                  1                  2
# 5848   Entire home/apt      NaN   1.0                  1                 63
# 5884      Private room      NaN   2.0                  1                  0
# 6398      Private room      NaN   1.0                  1                  0
# 6696   Entire home/apt      NaN   1.0                  1                  1
# 6924   Entire home/apt      NaN   2.0                  1                 17
# 7207   Entire home/apt      NaN   2.0                  1                 27
# 7490      Private room      NaN   1.0                  1                  0
# 7791      Private room      NaN   1.0                  1                 10
# 8568      Private room      NaN   1.0                  1                  0
# 8805      Private room      NaN   1.0                  1                 13
# 9183      Private room      NaN   1.0                  1                 39
# 9221   Entire home/apt      NaN   5.0                  1                  2
# 9595   Entire home/apt      NaN   3.0                  1                124
# 10238  Entire home/apt      NaN   1.0                  1                 33
# 12105  Entire home/apt      NaN   2.0                  1                 92
# 12630  Entire home/apt      NaN   1.0                  1                  1
# 13985     Private room      NaN   NaN                  1                  1
# 14354     Private room      NaN   1.0                  1                 97
# 14361  Entire home/apt      NaN   3.0                  1                 44
# 14812  Entire home/apt      NaN   1.0                  1                 37
# 15824  Entire home/apt      NaN   2.0                  1                  1
# 15999  Entire home/apt      NaN   3.0                  1                  1
# 16116  Entire home/apt      NaN   3.0                  1                  0
# 16243  Entire home/apt      NaN   2.0                  1                 77
# 17635  Entire home/apt      NaN   1.0                  1                 12
# 18373     Private room      NaN   1.0                  1                  1
# 18817     Private room      NaN   1.0                  1                  0
# 19226     Private room      NaN   1.0                  1                  0
# 19507     Private room      NaN   1.0                  1                  3
# 20016     Private room      NaN   1.0                  1                 49
# 20270  Entire home/apt      NaN   2.0                  1                  1
# 22685     Private room      NaN   1.0                  1                 10
# 23978     Private room      NaN   1.0                  1                 14
# 24575  Entire home/apt      NaN   3.0                  1                  2
# 24897      Shared room      NaN   1.0                  1                 10
# 25013  Entire home/apt      NaN   2.0                  1                  9
# 25679  Entire home/apt      NaN   4.0                  1                  4
# 26456     Private room      NaN   1.0                  1                 12
# 27089     Private room      NaN   1.0                  1                  4
# 28995     Private room      NaN   2.0                  1                  0
#
#       Price  Review Scores Rating Neighbourhood
# 333      49              85.00000      Brooklyn
# 583     105              90.00000      Brooklyn
# 1422     65             100.00000      Brooklyn
# 1930     96              96.00000      Brooklyn
# 2085    189              92.00000      Brooklyn
# 2643     60              89.00000      Brooklyn
# 3120     10                   NaN      Brooklyn
# 4013    123              92.00000      Brooklyn
# 4479    140              93.00000      Brooklyn
# 5028    350             100.00000      Brooklyn
# 5848    220              98.00000      Brooklyn
# 5884    135                   NaN      Brooklyn
# 6398     95                   NaN      Brooklyn
# 6696    120             100.00000      Brooklyn
# 6924    175              99.00000      Brooklyn
# 7207    160              93.00000      Brooklyn
# 7490    100                   NaN      Brooklyn
# 7791     52              94.00000      Brooklyn
# 8568    100                   NaN      Brooklyn
# 8805     70             100.00000      Brooklyn
# 9183    111              95.00000      Brooklyn
# 9221    300             100.00000      Brooklyn
# 9595    160              91.00000      Brooklyn
# 10238   140              99.00000      Brooklyn
# 12105    79              96.00000      Brooklyn
# 12630   150              91.99323      Brooklyn
# 13985    70             100.00000      Brooklyn
# 14354    60              97.00000      Brooklyn
# 14361   220              97.00000      Brooklyn
# 14812    50              90.00000      Brooklyn
# 15824    99             100.00000      Brooklyn
# 15999   145              80.00000      Brooklyn
# 16116   250                   NaN      Brooklyn
# 16243   175              93.00000      Brooklyn
# 17635   121              98.00000      Brooklyn
# 18373    83             100.00000      Brooklyn
# 18817    35                   NaN      Brooklyn
# 19226    48                   NaN      Brooklyn
# 19507   125             100.00000      Brooklyn
# 20016    95              83.00000      Brooklyn
# 20270   179             100.00000      Brooklyn
# 22685    65              94.00000      Brooklyn
# 23978    72              90.00000      Brooklyn
# 24575   250              90.00000      Brooklyn
# 24897    49              98.00000      Brooklyn
# 25013    70              83.00000      Brooklyn
# 25679   145              95.00000      Brooklyn
# 26456    48              83.00000      Brooklyn
# 27089    75              95.00000      Brooklyn
# 28995    75                   NaN      Brooklyn

# %%
df.loc[(df['Neighbourhood'] == 'Queens') & (df['Zipcode'].isna())]
# Out:
#         Host Id  Host Since                                 Name  \
# 5164    1528912  2011-12-22   Nice Private Room Beauty in Queens
# 8356    3114604  2012-07-31           Beautiful room/ Double bed
# 8576    3250450  2012-08-13   Location Marilda ( only for girls)
# 9510    3816303  2012-10-09    Astoria Room Close to Manhattan!!
# 9718    3956850  2012-10-23       NYC Astoria Big warm apartment
# 9999    4094837  2012-11-08  BIG, SUNNY Private room n Ridgewood
# 11111   4658655  2013-01-10   Lovely Private Room in Two Bedroom
# 12224   5577926  2013-03-22  clean and private room in safe area
# 13036   6291258  2013-05-08      Private room in Astoria, Queens
# 16201   9687105  2013-10-28     REDESIGNED LUXURY PENTHOUSE LOFT
# 18612  12864757  2014-03-06            private Room/Off Broadway
# 18973  13743787  2014-03-31                 Pretty room studio !
# 19271  14378462  2014-04-16   Spacious Astoria Room in Apartment
# 20821  17309971  2014-06-26                          The Tiffany
# 21094  17777286  2014-07-07  Snuggly, New Convenient Astoria 1BD
# 21154  17889038  2014-07-09                Home away from home!!
# 23365  22218694  2014-10-06   Zen Garden in the heart of Astoria
# 24465  24030482  2014-11-22  Room in queens covenient safe locat
# 24939  24764205  2014-12-12     Great one bedroom fully equipped
# 25997  27435723  2015-02-08  1 Bedroom Getaway In LIC GRAND VIEW
# 28793  36661779  2015-06-24        Spacious Central Astoria Apt!
# 30127  41425363  2015-08-13   Quaint Colonial with lots of charm
# 30183  41619645  2015-08-16                        MyPlace2Beach
# 30462  42952645  2015-08-30  Waterfront Penthouse~5min > TimesSQ
#
#       Neighbourhood  Property Type  Review Scores Rating (bin)  \
# 5164          Queens     Apartment                   95.000000
# 8356          Queens     Apartment                         NaN
# 8576          Queens     Apartment                  100.000000
# 9510          Queens     Apartment                   85.000000
# 9718          Queens     Apartment                  100.000000
# 9999          Queens     Apartment                         NaN
# 11111         Queens     Apartment                         NaN
# 12224         Queens     Apartment                  100.000000
# 13036         Queens     Apartment                   90.738659
# 16201         Queens     Apartment                   90.000000
# 18612         Queens     Apartment                         NaN
# 18973         Queens     Apartment                   95.000000
# 19271         Queens     Apartment                         NaN
# 20821         Queens         House                  100.000000
# 21094         Queens     Apartment                         NaN
# 21154         Queens     Apartment                         NaN
# 23365         Queens     Apartment                  100.000000
# 24465         Queens         House                         NaN
# 24939         Queens     Apartment                         NaN
# 25997         Queens     Apartment                  100.000000
# 28793         Queens     Apartment                  100.000000
# 30127         Queens         House                         NaN
# 30183         Queens         House                  100.000000
# 30462         Queens     Apartment                         NaN
#
#              Room Type  Zipcode  Beds  Number of Records  Number Of Reviews  \
# 5164      Private room      NaN   1.0                  1                 23
# 8356      Private room      NaN   1.0                  1                  0
# 8576      Private room      NaN   1.0                  1                  1
# 9510      Private room      NaN   1.0                  1                 82
# 9718   Entire home/apt      NaN   1.0                  1                  2
# 9999      Private room      NaN   1.0                  1                  0
# 11111     Private room      NaN   1.0                  1                  0
# 12224     Private room      NaN   1.0                  1                  7
# 13036     Private room      NaN   1.0                  1                  2
# 16201     Private room      NaN   1.0                  1                 32
# 18612     Private room      NaN   1.0                  1                  0
# 18973     Private room      NaN   3.0                  1                 54
# 19271     Private room      NaN   1.0                  1                  0
# 20821     Private room      NaN   1.0                  1                  5
# 21094      Shared room      NaN   1.0                  1                  0
# 21154     Private room      NaN   1.0                  1                  0
# 23365  Entire home/apt      NaN   2.0                  1                  2
# 24465     Private room      NaN   1.0                  1                  0
# 24939  Entire home/apt      NaN   1.0                  1                  0
# 25997  Entire home/apt      NaN   1.0                  1                  1
# 28793  Entire home/apt      NaN   2.0                  1                  3
# 30127  Entire home/apt      NaN   3.0                  1                  0
# 30183  Entire home/apt      NaN   3.0                  1                  1
# 30462     Private room      NaN   1.0                  1                  0
#
#       Price  Review Scores Rating Neighbourhood
# 5164     59              95.00000        Queens
# 8356     84                   NaN        Queens
# 8576     43             100.00000        Queens
# 9510     56              86.00000        Queens
# 9718     89             100.00000        Queens
# 9999     75                   NaN        Queens
# 11111    89                   NaN        Queens
# 12224    51             100.00000        Queens
# 13036    65              91.99323        Queens
# 16201   135              94.00000        Queens
# 18612    60                   NaN        Queens
# 18973    75              95.00000        Queens
# 19271    67                   NaN        Queens
# 20821    49             100.00000        Queens
# 21094    75                   NaN        Queens
# 21154    65                   NaN        Queens
# 23365   220             100.00000        Queens
# 24465    99                   NaN        Queens
# 24939   150                   NaN        Queens
# 25997   200             100.00000        Queens
# 28793    69             100.00000        Queens
# 30127   140                   NaN        Queens
# 30183   200             100.00000        Queens
# 30462    99                   NaN        Queens

# %%
df.loc[(df['Neighbourhood'] == 'Bronx') & (df['Zipcode'].isna())]
# Out:
#         Host Id  Host Since                                 Name  \
# 18911  13664245  2014-03-29     Private, Large room with closet!
# 27217  31826196  2015-04-23  Peace and silence in New York?! Yes
#
#       Neighbourhood  Property Type  Review Scores Rating (bin)     Room Type  \
# 18911          Bronx         House                        90.0  Private room
# 27217          Bronx     Apartment                        80.0  Private room
#
#        Zipcode  Beds  Number of Records  Number Of Reviews Price  \
# 18911      NaN   4.0                  1                 24    48
# 27217      NaN   4.0                  1                  6   120
#
#        Review Scores Rating Neighbourhood
# 18911                  92.0         Bronx
# 27217                  80.0         Bronx

# %%
df.loc[(df['Neighbourhood'] == 'Staten Island') & (df['Zipcode'].isna())]
# Out:
#        Host Id  Host Since                                 Name  \
# 11693  5133304  2013-02-18  Your home in NYC close to Manhattan
#
#       Neighbourhood  Property Type  Review Scores Rating (bin)  \
# 11693  Staten Island         House                        90.0
#
#              Room Type  Zipcode  Beds  Number of Records  Number Of Reviews  \
# 11693  Entire home/apt      NaN   2.0                  1                 24
#
#       Price  Review Scores Rating  Neighbourhood
# 11693    80                  91.0  Staten Island

# %%
print(NaN_count)
# Out:
# Host Id                         0
# Host Since                      2
# Name                            0
# Neighbourhood                   0
# Property Type                   2
# Review Scores Rating (bin)      0
# Room Type                       0
# Zipcode                       104
# Beds                           46
# Number of Records               0
# Number Of Reviews               0
# Price                           0
# Review Scores Rating            0
# dtype: int64

# %%
df.to_csv('airbnb.csv' ,index=False)
